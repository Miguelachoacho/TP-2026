# %%
#Lib Imports 
import pandas as pd
import numpy as np
import warnings

# ignorar todos los warnings
warnings.filterwarnings('ignore')


from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn_pandas import DataFrameMapper
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error


from tensorflow.keras.models import Sequential, clone_model,save_model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import Callback,EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
# cargamos el dataset principal con datos historicos y variables externas
df = pd.read_csv("../data/full_data.csv", parse_dates=["Date"], dayfirst=False)

# ordenamos por fecha
df = df.sort_values("Date").reset_index(drop=True)

# mostramos info general del dataset
print("columnas disponibles:")
print(df.columns.tolist())

print("\nprimeras filas:")
print(df.tail()) #Vemos los ultimos datos

print("\ntipos de datos:")
print(df.dtypes)
# Out:
# columnas disponibles:
# ['Date', 'Close', 'High', 'Low', 'Open', 'Volume', 'Daily_Change', 'Volatility', 'Pct_Change', 'Volume_Change_pct', 'SMA_7', 'SMA_30', 'Rolling_volatility_30', 'BTC_Close_t-1', 'BTC_Close_t-2', 'BTC_Close_t-3', 'BTC_Close_t-7', 'fng_value', 'fng_classification', 'fng_diff_day', 'fng_SMA_7', 'fng_SMA_30', 'fng_trend', 'Is_Halving_Date', 'Block_reward']
#
# primeras filas:
#            Date         Close          High           Low          Open  \
# 3115 2026-08-13  63402.171875  63926.332031  62799.289062  63404.425781
# 3116 2026-08-14  62975.593750  63551.562500  62487.699219  63402.089844
# 3117 2026-08-15  63024.320312  63119.132812  62850.960938  62974.335938
# 3118 2026-08-16  62818.652344  63310.777344  62648.574219  63023.421875
# 3119 2026-08-18  64140.011719  64487.648438  64166.785156  64487.648438
#
#            Volume  Daily_Change   Volatility  Pct_Change  Volume_Change_pct  \
# 3115  18765583756     -2.253906  1127.042969   -0.000004          -0.186364
# 3116  20280053024   -426.496094  1063.863281   -0.006728           0.080705
# 3117  10033057106     49.984375   268.171875    0.000774          -0.505275
# 3118   9078986635   -204.769531   662.203125   -0.003263          -0.095093
# 3119  21063837696   -347.636719   320.863281    0.021035           1.320065
#
#       ...  BTC_Close_t-3  BTC_Close_t-7  fng_value  fng_classification  \
# 3115  ...   63910.585938   64262.113281       29.0                Fear
# 3116  ...   63551.875000   64880.191406       29.0                Fear
# 3117  ...   63402.433594   64904.687500       34.0                Fear
# 3118  ...   63402.171875   64844.886719       34.0                Fear
# 3119  ...   62975.593750   63910.585938       41.0                Fear
#
#       fng_diff_day  fng_SMA_7  fng_SMA_30  fng_trend Is_Halving_Date  \
# 3115           2.0  29.285714   27.800000   1.485714               0
# 3116           0.0  29.285714   27.933333   1.352381               0
# 3117           5.0  29.857143   28.233333   1.623810               0
# 3118           0.0  30.285714   28.466667   1.819048               0
# 3119          10.0  32.142857   29.100000   3.042857               0
#
#       Block_reward
# 3115         3.125
# 3116         3.125
# 3117         3.125
# 3118         3.125
# 3119           NaN
#
# [5 rows x 25 columns]
#
# tipos de datos:
# Date                     datetime64[ns]
# Close                           float64
# High                            float64
# Low                             float64
# Open                            float64
# Volume                            int64
# Daily_Change                    float64
# Volatility                      float64
# Pct_Change                      float64
# Volume_Change_pct               float64
# SMA_7                           float64
# SMA_30                          float64
# Rolling_volatility_30           float64
# BTC_Close_t-1                   float64
# BTC_Close_t-2                   float64
# BTC_Close_t-3                   float64
# BTC_Close_t-7                   float64
# fng_value                       float64
# fng_classification               object
# fng_diff_day                    float64
# fng_SMA_7                       float64
# fng_SMA_30                      float64
# fng_trend                       float64
# Is_Halving_Date                   int64
# Block_reward                    float64
# dtype: object

# %%
# generacion de targets y analisis de correlacion

# generamos los 7 targets (precio de cierre futuro)
for i in range(1, 8):
    df[f"Close_t+{i}"] = df["Close"].shift(-i)

# eliminamos las filas sin datos completos (las ultimas 7)
df = df.dropna(subset=[f"Close_t+{i}" for i in range(1, 8)]).reset_index(drop=True)

# definimos las features numericas disponibles (todas menos las categoricas o de texto)
available_features = [col for col in df.columns if df[col].dtype != "object" and col not in [f"Close_t+{i}" for i in range(1, 8)]]

# lista de targets
targets = [f"Close_t+{i}" for i in range(1, 8)]

# %%
# seleccion de features mas correlacionadas

selected_features = ['Date','Volume','Pct_Change','Volume_Change_pct','Volatility','SMA_7','SMA_30',
             'fng_value','fng_SMA_7','fng_SMA_30','BTC_Close_t-1','BTC_Close_t-2','BTC_Close_t-3','BTC_Close_t-7','Rolling_volatility_30', 'Block_reward'] ##Agrego dos features más *Nota interna: menos es más*


# dejamos solo las columnas seleccionadas y los 7 targets
keep_cols = selected_features + [f"Close_t+{i}" for i in range(1, 8)]
df = df[keep_cols].copy()

print(f"dataset final listo para entrenamiento, con {len(selected_features)} features y 7 targets\n")
print(df.head())
# Out:
# dataset final listo para entrenamiento, con 16 features y 7 targets
#
#         Date       Volume  Pct_Change  Volume_Change_pct   Volatility  SMA_7  \
# 0 2018-02-01   9959400448         NaN                NaN  1476.519531    NaN
# 1 2018-02-02  12726899712   -0.037052           0.277878  1345.790039    NaN
# 2 2018-02-03   7263790080    0.038973          -0.429257  1179.120117    NaN
# 3 2018-02-04   7073549824   -0.097865          -0.026190  1303.649902    NaN
# 4 2018-02-05   9285289984   -0.159688           0.312678  1608.159668    NaN
#
#    SMA_30  fng_value  fng_SMA_7  fng_SMA_30  ...  BTC_Close_t-7  \
# 0     NaN       30.0        NaN         NaN  ...            NaN
# 1     NaN       15.0        NaN         NaN  ...            NaN
# 2     NaN       40.0        NaN         NaN  ...            NaN
# 3     NaN       24.0        NaN         NaN  ...            NaN
# 4     NaN       11.0        NaN         NaN  ...            NaN
#
#    Rolling_volatility_30  Block_reward    Close_t+1    Close_t+2    Close_t+3  \
# 0                    NaN          12.5  8830.750000  9174.910156  8277.009766
# 1                    NaN          12.5  9174.910156  8277.009766  6955.270020
# 2                    NaN          12.5  8277.009766  6955.270020  7754.000000
# 3                    NaN          12.5  6955.270020  7754.000000  7621.299805
# 4                    NaN          12.5  7754.000000  7621.299805  8265.589844
#
#      Close_t+4    Close_t+5    Close_t+6    Close_t+7
# 0  6955.270020  7754.000000  7621.299805  8265.589844
# 1  7754.000000  7621.299805  8265.589844  8736.980469
# 2  7621.299805  8265.589844  8736.980469  8621.900391
# 3  8265.589844  8736.980469  8621.900391  8129.970215
# 4  8736.980469  8621.900391  8129.970215  8926.570312
#
# [5 rows x 23 columns]

# %%
# features: todas las columnas numericas excepto los targets y la fecha
targets = [f"Close_t+{i}" for i in range(1, 8)]
features = [c for c in df.columns if c not in targets + ["Date"]]

# diccionarios para guardar X e Y por horizonte
X_dict = {}
Y_dict = {}

for i in range(1, 8):
    tcol = f"Close_t+{i}"
    X_dict[i] = df[features].copy()
    Y_dict[i] = df[[tcol]].copy()

# mostrar shapes para confirmar
print("resumen de shapes por horizonte (i -> X.shape -> y.shape):\n")
for i in range(1, 8):
    print(f"t+{i}: X {X_dict[i].shape} -> Y {Y_dict[i].shape}")

# ejemplo: mostrar las primeras filas del horizonte 1
print("\nprimeras filas - ejemplo horizonte t+1 (X, Y):")
print(X_dict[1].head())
print(Y_dict[1].head())
# Out:
# resumen de shapes por horizonte (i -> X.shape -> y.shape):
#
# t+1: X (3113, 15) -> Y (3113, 1)
# t+2: X (3113, 15) -> Y (3113, 1)
# t+3: X (3113, 15) -> Y (3113, 1)
# t+4: X (3113, 15) -> Y (3113, 1)
# t+5: X (3113, 15) -> Y (3113, 1)
# t+6: X (3113, 15) -> Y (3113, 1)
# t+7: X (3113, 15) -> Y (3113, 1)
#
# primeras filas - ejemplo horizonte t+1 (X, Y):
#         Volume  Pct_Change  Volume_Change_pct   Volatility  SMA_7  SMA_30  \
# 0   9959400448         NaN                NaN  1476.519531    NaN     NaN
# 1  12726899712   -0.037052           0.277878  1345.790039    NaN     NaN
# 2   7263790080    0.038973          -0.429257  1179.120117    NaN     NaN
# 3   7073549824   -0.097865          -0.026190  1303.649902    NaN     NaN
# 4   9285289984   -0.159688           0.312678  1608.159668    NaN     NaN
#
#    fng_value  fng_SMA_7  fng_SMA_30  BTC_Close_t-1  BTC_Close_t-2  \
# 0       30.0        NaN         NaN            NaN            NaN
# 1       15.0        NaN         NaN    9170.540039            NaN
# 2       40.0        NaN         NaN    8830.750000    9170.540039
# 3       24.0        NaN         NaN    9174.910156    8830.750000
# 4       11.0        NaN         NaN    8277.009766    9174.910156
#
#    BTC_Close_t-3  BTC_Close_t-7  Rolling_volatility_30  Block_reward
# 0            NaN            NaN                    NaN          12.5
# 1            NaN            NaN                    NaN          12.5
# 2            NaN            NaN                    NaN          12.5
# 3    9170.540039            NaN                    NaN          12.5
# 4    8830.750000            NaN                    NaN          12.5
#      Close_t+1
# 0  8830.750000
# 1  9174.910156
# 2  8277.009766
# 3  6955.270020
# 4  7754.000000

# %%
#targets y features
targets = [f"Close_t+{i}" for i in range(1, 8)]  # 7 targets, 7 modelos
features = [col for col in df.columns if col not in targets + ['Date']]  # usamos todas las features excepto targets y date

#columnas a escalar
cols_scaler = features  # todas las numericas

#crear mapper
# mapper aplica: primero imputa valores nulos con la mediana, luego escala con robust scaler
mapper = DataFrameMapper([
    (cols_scaler, [SimpleImputer(strategy='median'), RobustScaler()])
], input_df=True, df_out=True)

#definir modelos
models_dict = {
    "LinearRegression": LinearRegression(),
    "KNN": KNeighborsRegressor(n_neighbors=15),
    "DecisionTree": DecisionTreeRegressor(max_depth=None, random_state=42),
    "RandomForest": RandomForestRegressor(n_estimators=100, random_state=42)
}

#pipelines vacios por cada target
pipelines = {}
for target in targets:
    # aca solo definimos el pipeline base, luego le metemos cada modelo de la lista, 28 pipelines
    pipelines[target] = {}
    
    for model_name, model in models_dict.items():
        pipeline = Pipeline([
            ('mapper', mapper),
            ('model', model)
        ])
        pipelines[target][model_name] = pipeline

# %%
# definimos tamaño de test final
test_size = 0.15 #Aumento un poco más el tamaño para test
n_test = int(len(df) * test_size)

# separamos test final
train_val_df = df.iloc[:-n_test].reset_index(drop=True)
test_df = df.iloc[-n_test:].reset_index(drop=True)

n_splits = 6
tscv = TimeSeriesSplit(n_splits=n_splits)

# diccionarios para guardar índices por fold y por target
folds_idx = {target: [] for target in targets}

print(f"División en {n_splits} folds (train/val) por fechas:\n")
for target in targets:
    print(f" Target: {target}")
    X = train_val_df[features]
    y = train_val_df[[target]]

    for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
        # guardar indices
        folds_idx[target].append((train_idx, val_idx))

        # fechas para mostrar
        start_train = train_val_df.iloc[train_idx[0]]['Date']
        end_train   = train_val_df.iloc[train_idx[-1]]['Date']
        start_val   = train_val_df.iloc[val_idx[0]]['Date']
        end_val     = train_val_df.iloc[val_idx[-1]]['Date']

        print(f"Fold {fold+1}:")
        print(f"  Train: {start_train.date()} -> {end_train.date()} ({len(train_idx)} filas)")
        print(f"  Val:   {start_val.date()} -> {end_val.date()} ({len(val_idx)} filas)\n")

# mostrar tamaño test final
print(f"Test final: {test_df['Date'].min().date()} -> {test_df['Date'].max().date()} ({len(test_df)} filas)")
# Out:
# División en 6 folds (train/val) por fechas:
#
#  Target: Close_t+1
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+2
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+3
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+4
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+5
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+6
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
#  Target: Close_t+7
# Fold 1:
#   Train: 2018-02-01 -> 2019-02-14 (379 filas)
#   Val:   2019-02-15 -> 2020-02-27 (378 filas)
#
# Fold 2:
#   Train: 2018-02-01 -> 2020-02-27 (757 filas)
#   Val:   2020-02-28 -> 2021-03-11 (378 filas)
#
# Fold 3:
#   Train: 2018-02-01 -> 2021-03-11 (1135 filas)
#   Val:   2021-03-12 -> 2022-03-24 (378 filas)
#
# Fold 4:
#   Train: 2018-02-01 -> 2022-03-24 (1513 filas)
#   Val:   2022-03-25 -> 2023-04-06 (378 filas)
#
# Fold 5:
#   Train: 2018-02-01 -> 2023-04-06 (1891 filas)
#   Val:   2023-04-07 -> 2024-04-18 (378 filas)
#
# Fold 6:
#   Train: 2018-02-01 -> 2024-04-18 (2269 filas)
#   Val:   2024-04-19 -> 2025-05-01 (378 filas)
#
# Test final: 2025-05-02 -> 2026-08-10 (466 filas)

# %%
n_splits = 7
tscv = TimeSeriesSplit(n_splits=n_splits)

# diccionario para resultados
cv_results = {}  # {target: {model_name: [fold_results]}}

for target in targets:
    print(f"\n Target: {target}")
    X = df[features]
    y = df[[target]]

    cv_results[target] = {}

    for model_name, pipeline in pipelines[target].items():
        print(f"\n Modelo: {model_name}")
        fold_results = []

        for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

            # entrenar
            pipeline.fit(X_train, y_train)

            # predecir
            y_pred_train = pipeline.predict(X_train)
            y_pred_val   = pipeline.predict(X_val)

            # métricas
            mae_train = mean_absolute_error(y_train, y_pred_train)
            rmse_train = mean_squared_error(y_train, y_pred_train)**0.5

            mae_val = mean_absolute_error(y_val, y_pred_val)
            rmse_val = mean_squared_error(y_val, y_pred_val)**0.5

            fold_results.append({
                "fold": fold+1,
                "MAE_train": mae_train, "RMSE_train": rmse_train,
                "MAE_val": mae_val, "RMSE_val": rmse_val
            })

            print(f"Fold {fold+1}: Train MAE {mae_train:.2f}, RMSE {rmse_train:.2f} | "
                  f"Val MAE {mae_val:.2f}, RMSE {rmse_val:.2f}")

        cv_results[target][model_name] = fold_results
# Out:
#  Target: Close_t+1
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 192.96, RMSE 290.03 | Val MAE 417.49, RMSE 580.26
# Fold 2: Train MAE 211.35, RMSE 330.76 | Val MAE 803.67, RMSE 1458.32
# Fold 3: Train MAE 412.31, RMSE 788.31 | Val MAE 1787.13, RMSE 2309.41
# Fold 4: Train MAE 745.97, RMSE 1214.95 | Val MAE 492.78, RMSE 749.49
# Fold 5: Train MAE 698.29, RMSE 1138.31 | Val MAE 896.41, RMSE 1419.57
# Fold 6: Train MAE 744.14, RMSE 1208.56 | Val MAE 1917.46, RMSE 2560.45
# Fold 7: Train MAE 922.51, RMSE 1484.71 | Val MAE 1661.25, RMSE 2261.61
#
#  Modelo: KNN
# Fold 1: Train MAE 314.52, RMSE 481.35 | Val MAE 962.64, RMSE 1165.61
# Fold 2: Train MAE 318.73, RMSE 496.34 | Val MAE 11349.22, RMSE 19734.16
# Fold 3: Train MAE 545.76, RMSE 1049.47 | Val MAE 3692.68, RMSE 4538.94
# Fold 4: Train MAE 1425.57, RMSE 2173.32 | Val MAE 8266.99, RMSE 9228.25
# Fold 5: Train MAE 1299.70, RMSE 1981.72 | Val MAE 4416.39, RMSE 5570.98
# Fold 6: Train MAE 1508.26, RMSE 2257.61 | Val MAE 22160.89, RMSE 26494.25
# Fold 7: Train MAE 1904.51, RMSE 2978.77 | Val MAE 5773.09, RMSE 6974.70
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 724.70, RMSE 949.13
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 11027.51, RMSE 19465.80
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 5392.42, RMSE 6589.46
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 4552.78, RMSE 5318.05
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 2317.24, RMSE 3252.61
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 19748.49, RMSE 24652.50
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 6260.82, RMSE 8145.26
#
#  Modelo: RandomForest
# Fold 1: Train MAE 83.33, RMSE 131.78 | Val MAE 487.96, RMSE 697.16
# Fold 2: Train MAE 83.00, RMSE 128.54 | Val MAE 11022.21, RMSE 19567.47
# Fold 3: Train MAE 143.69, RMSE 293.85 | Val MAE 5332.31, RMSE 6168.85
# Fold 4: Train MAE 245.67, RMSE 449.68 | Val MAE 2015.91, RMSE 2478.55
# Fold 5: Train MAE 239.66, RMSE 419.68 | Val MAE 1867.20, RMSE 2895.19
# Fold 6: Train MAE 256.01, RMSE 451.89 | Val MAE 19537.29, RMSE 24723.24
# Fold 7: Train MAE 309.13, RMSE 538.13 | Val MAE 3395.60, RMSE 4291.80
#
#  Target: Close_t+2
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 257.84, RMSE 379.67 | Val MAE 555.22, RMSE 742.98
# Fold 2: Train MAE 295.13, RMSE 440.56 | Val MAE 1128.71, RMSE 1950.72
# Fold 3: Train MAE 551.30, RMSE 1014.05 | Val MAE 2454.49, RMSE 3108.29
# Fold 4: Train MAE 982.10, RMSE 1570.06 | Val MAE 691.07, RMSE 1030.81
# Fold 5: Train MAE 925.81, RMSE 1477.71 | Val MAE 1161.63, RMSE 1794.42
# Fold 6: Train MAE 976.50, RMSE 1545.92 | Val MAE 2471.82, RMSE 3282.03
# Fold 7: Train MAE 1195.02, RMSE 1885.53 | Val MAE 2221.73, RMSE 2926.11
#
#  Modelo: KNN
# Fold 1: Train MAE 331.73, RMSE 498.55 | Val MAE 990.59, RMSE 1211.49
# Fold 2: Train MAE 359.95, RMSE 549.10 | Val MAE 11557.72, RMSE 19981.49
# Fold 3: Train MAE 607.46, RMSE 1159.20 | Val MAE 4115.54, RMSE 5098.66
# Fold 4: Train MAE 1500.20, RMSE 2299.31 | Val MAE 8275.03, RMSE 9261.75
# Fold 5: Train MAE 1383.21, RMSE 2116.58 | Val MAE 4545.25, RMSE 5793.75
# Fold 6: Train MAE 1595.74, RMSE 2398.46 | Val MAE 22584.60, RMSE 26877.96
# Fold 7: Train MAE 2008.96, RMSE 3145.26 | Val MAE 5792.93, RMSE 7076.95
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1137.56, RMSE 1407.45
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 11489.44, RMSE 19845.26
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 7108.85, RMSE 8181.24
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 3269.57, RMSE 3810.71
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 3320.73, RMSE 4651.05
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 21092.87, RMSE 26118.53
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 4157.43, RMSE 5608.48
#
#  Modelo: RandomForest
# Fold 1: Train MAE 92.97, RMSE 148.23 | Val MAE 646.54, RMSE 904.55
# Fold 2: Train MAE 100.47, RMSE 150.70 | Val MAE 11343.31, RMSE 19864.75
# Fold 3: Train MAE 156.99, RMSE 292.96 | Val MAE 6396.48, RMSE 7308.48
# Fold 4: Train MAE 302.99, RMSE 541.92 | Val MAE 2348.55, RMSE 2930.78
# Fold 5: Train MAE 291.54, RMSE 509.76 | Val MAE 2443.17, RMSE 3513.66
# Fold 6: Train MAE 318.05, RMSE 552.42 | Val MAE 20797.17, RMSE 25920.39
# Fold 7: Train MAE 377.72, RMSE 651.74 | Val MAE 3664.77, RMSE 4648.40
#
#  Target: Close_t+3
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 319.06, RMSE 446.89 | Val MAE 585.36, RMSE 794.34
# Fold 2: Train MAE 371.91, RMSE 535.03 | Val MAE 1445.77, RMSE 2459.64
# Fold 3: Train MAE 682.34, RMSE 1214.98 | Val MAE 2966.12, RMSE 3765.08
# Fold 4: Train MAE 1160.84, RMSE 1860.76 | Val MAE 884.40, RMSE 1296.11
# Fold 5: Train MAE 1105.13, RMSE 1761.41 | Val MAE 1454.66, RMSE 2161.96
# Fold 6: Train MAE 1174.99, RMSE 1841.97 | Val MAE 2890.43, RMSE 3839.11
# Fold 7: Train MAE 1419.31, RMSE 2224.48 | Val MAE 2557.94, RMSE 3428.52
#
#  Modelo: KNN
# Fold 1: Train MAE 350.51, RMSE 525.04 | Val MAE 999.21, RMSE 1235.93
# Fold 2: Train MAE 395.07, RMSE 598.18 | Val MAE 11779.36, RMSE 20221.31
# Fold 3: Train MAE 663.55, RMSE 1252.61 | Val MAE 4598.91, RMSE 5690.22
# Fold 4: Train MAE 1596.76, RMSE 2431.61 | Val MAE 8301.26, RMSE 9307.84
# Fold 5: Train MAE 1476.08, RMSE 2247.32 | Val MAE 4727.33, RMSE 5989.21
# Fold 6: Train MAE 1686.76, RMSE 2521.73 | Val MAE 22998.04, RMSE 27159.03
# Fold 7: Train MAE 2130.34, RMSE 3301.13 | Val MAE 5693.06, RMSE 7091.82
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1017.95, RMSE 1307.49
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 11635.06, RMSE 19953.70
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 7102.74, RMSE 8362.95
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 4551.28, RMSE 5369.90
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 4070.96, RMSE 5200.02
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 21862.12, RMSE 26409.42
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 4800.06, RMSE 6263.57
#
#  Modelo: RandomForest
# Fold 1: Train MAE 99.21, RMSE 154.90 | Val MAE 734.64, RMSE 1021.12
# Fold 2: Train MAE 108.47, RMSE 163.98 | Val MAE 11554.26, RMSE 20088.25
# Fold 3: Train MAE 158.92, RMSE 291.40 | Val MAE 7396.41, RMSE 8624.52
# Fold 4: Train MAE 317.51, RMSE 571.16 | Val MAE 2883.37, RMSE 3559.24
# Fold 5: Train MAE 310.38, RMSE 553.53 | Val MAE 2872.67, RMSE 3993.19
# Fold 6: Train MAE 341.68, RMSE 608.36 | Val MAE 21220.24, RMSE 26179.67
# Fold 7: Train MAE 415.75, RMSE 714.95 | Val MAE 3835.21, RMSE 4825.13
#
#  Target: Close_t+4
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 358.50, RMSE 502.86 | Val MAE 717.05, RMSE 951.93
# Fold 2: Train MAE 429.80, RMSE 614.62 | Val MAE 1737.98, RMSE 2929.76
# Fold 3: Train MAE 790.34, RMSE 1361.34 | Val MAE 3486.71, RMSE 4423.48
# Fold 4: Train MAE 1320.17, RMSE 2118.41 | Val MAE 1052.92, RMSE 1502.38
# Fold 5: Train MAE 1264.29, RMSE 2009.22 | Val MAE 1714.71, RMSE 2509.14
# Fold 6: Train MAE 1354.82, RMSE 2107.59 | Val MAE 3311.58, RMSE 4339.89
# Fold 7: Train MAE 1630.70, RMSE 2524.88 | Val MAE 2829.48, RMSE 3843.70
#
#  Modelo: KNN
# Fold 1: Train MAE 367.43, RMSE 553.79 | Val MAE 1031.90, RMSE 1279.84
# Fold 2: Train MAE 425.91, RMSE 646.46 | Val MAE 11967.48, RMSE 20422.56
# Fold 3: Train MAE 709.46, RMSE 1325.15 | Val MAE 5096.64, RMSE 6301.35
# Fold 4: Train MAE 1667.22, RMSE 2560.82 | Val MAE 8332.37, RMSE 9325.84
# Fold 5: Train MAE 1554.21, RMSE 2377.59 | Val MAE 4856.83, RMSE 6179.37
# Fold 6: Train MAE 1779.24, RMSE 2662.23 | Val MAE 23287.35, RMSE 27423.53
# Fold 7: Train MAE 2239.12, RMSE 3448.45 | Val MAE 5736.77, RMSE 7159.82
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1239.53, RMSE 1550.71
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 12175.66, RMSE 20717.39
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 7592.74, RMSE 8890.21
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 6655.55, RMSE 7701.00
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 4170.30, RMSE 5433.58
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 22115.53, RMSE 26468.45
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 5502.42, RMSE 6910.78
#
#  Modelo: RandomForest
# Fold 1: Train MAE 95.30, RMSE 144.07 | Val MAE 790.86, RMSE 1106.43
# Fold 2: Train MAE 107.33, RMSE 162.67 | Val MAE 11791.98, RMSE 20346.43
# Fold 3: Train MAE 166.28, RMSE 297.80 | Val MAE 7907.80, RMSE 9198.01
# Fold 4: Train MAE 330.49, RMSE 609.22 | Val MAE 3534.54, RMSE 4365.69
# Fold 5: Train MAE 318.22, RMSE 567.54 | Val MAE 3278.06, RMSE 4570.70
# Fold 6: Train MAE 364.44, RMSE 654.59 | Val MAE 21608.09, RMSE 26430.79
# Fold 7: Train MAE 431.85, RMSE 750.28 | Val MAE 4059.77, RMSE 5111.18
#
#  Target: Close_t+5
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 405.18, RMSE 546.41 | Val MAE 846.56, RMSE 1115.97
# Fold 2: Train MAE 488.07, RMSE 689.22 | Val MAE 1986.89, RMSE 3350.26
# Fold 3: Train MAE 883.72, RMSE 1494.41 | Val MAE 3968.28, RMSE 5025.42
# Fold 4: Train MAE 1475.91, RMSE 2360.96 | Val MAE 1165.69, RMSE 1675.02
# Fold 5: Train MAE 1408.60, RMSE 2238.28 | Val MAE 1919.26, RMSE 2815.90
# Fold 6: Train MAE 1504.46, RMSE 2347.50 | Val MAE 3728.40, RMSE 4801.30
# Fold 7: Train MAE 1805.53, RMSE 2789.43 | Val MAE 3145.52, RMSE 4266.17
#
#  Modelo: KNN
# Fold 1: Train MAE 382.41, RMSE 569.87 | Val MAE 1080.12, RMSE 1347.28
# Fold 2: Train MAE 452.93, RMSE 681.63 | Val MAE 12146.91, RMSE 20545.41
# Fold 3: Train MAE 747.47, RMSE 1381.95 | Val MAE 5526.60, RMSE 6776.05
# Fold 4: Train MAE 1723.05, RMSE 2658.55 | Val MAE 8364.09, RMSE 9382.25
# Fold 5: Train MAE 1624.21, RMSE 2482.78 | Val MAE 5005.81, RMSE 6372.00
# Fold 6: Train MAE 1847.83, RMSE 2774.95 | Val MAE 23633.05, RMSE 27772.00
# Fold 7: Train MAE 2334.32, RMSE 3548.63 | Val MAE 5569.31, RMSE 7047.23
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1164.39, RMSE 1545.63
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 12737.75, RMSE 21223.58
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 8858.47, RMSE 10375.03
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 8168.21, RMSE 9556.70
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 4818.06, RMSE 6282.33
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 22906.32, RMSE 27642.76
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 9533.70, RMSE 11801.23
#
#  Modelo: RandomForest
# Fold 1: Train MAE 92.76, RMSE 137.43 | Val MAE 933.50, RMSE 1274.53
# Fold 2: Train MAE 105.30, RMSE 160.32 | Val MAE 12045.87, RMSE 20555.83
# Fold 3: Train MAE 162.54, RMSE 289.95 | Val MAE 8316.24, RMSE 9717.04
# Fold 4: Train MAE 331.99, RMSE 607.73 | Val MAE 4790.11, RMSE 5757.78
# Fold 5: Train MAE 320.85, RMSE 586.30 | Val MAE 3854.80, RMSE 5207.87
# Fold 6: Train MAE 368.54, RMSE 669.47 | Val MAE 22574.61, RMSE 27444.98
# Fold 7: Train MAE 440.37, RMSE 777.88 | Val MAE 5073.97, RMSE 6465.22
#
#  Target: Close_t+6
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 436.58, RMSE 588.81 | Val MAE 912.47, RMSE 1215.40
# Fold 2: Train MAE 533.15, RMSE 751.17 | Val MAE 2232.31, RMSE 3761.86
# Fold 3: Train MAE 975.71, RMSE 1625.13 | Val MAE 4526.33, RMSE 5688.80
# Fold 4: Train MAE 1623.94, RMSE 2591.64 | Val MAE 1253.64, RMSE 1831.35
# Fold 5: Train MAE 1542.55, RMSE 2455.41 | Val MAE 2118.75, RMSE 3079.26
# Fold 6: Train MAE 1647.39, RMSE 2568.77 | Val MAE 4025.33, RMSE 5188.19
# Fold 7: Train MAE 1957.55, RMSE 3026.54 | Val MAE 3479.31, RMSE 4678.52
#
#  Modelo: KNN
# Fold 1: Train MAE 387.68, RMSE 590.48 | Val MAE 1112.64, RMSE 1396.87
# Fold 2: Train MAE 477.46, RMSE 718.60 | Val MAE 12291.15, RMSE 20644.72
# Fold 3: Train MAE 789.79, RMSE 1436.07 | Val MAE 5895.93, RMSE 7198.62
# Fold 4: Train MAE 1767.91, RMSE 2741.73 | Val MAE 8369.04, RMSE 9410.07
# Fold 5: Train MAE 1681.24, RMSE 2578.88 | Val MAE 5143.35, RMSE 6584.59
# Fold 6: Train MAE 1908.90, RMSE 2888.84 | Val MAE 23966.43, RMSE 28080.05
# Fold 7: Train MAE 2417.05, RMSE 3701.30 | Val MAE 5493.31, RMSE 7059.17
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1123.33, RMSE 1468.67
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 12098.06, RMSE 20498.27
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 8548.80, RMSE 10350.43
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 8894.94, RMSE 10002.26
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 5009.65, RMSE 6714.57
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 23070.05, RMSE 27643.08
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 8886.37, RMSE 12262.87
#
#  Modelo: RandomForest
# Fold 1: Train MAE 94.46, RMSE 147.48 | Val MAE 1087.49, RMSE 1443.73
# Fold 2: Train MAE 108.47, RMSE 170.93 | Val MAE 12173.68, RMSE 20686.63
# Fold 3: Train MAE 166.15, RMSE 316.35 | Val MAE 8715.47, RMSE 10225.99
# Fold 4: Train MAE 338.26, RMSE 631.35 | Val MAE 5984.77, RMSE 6992.39
# Fold 5: Train MAE 332.64, RMSE 615.84 | Val MAE 3779.42, RMSE 5221.21
# Fold 6: Train MAE 378.42, RMSE 699.29 | Val MAE 23451.81, RMSE 28165.49
# Fold 7: Train MAE 445.20, RMSE 788.03 | Val MAE 5561.73, RMSE 7369.00
#
#  Target: Close_t+7
#
#  Modelo: LinearRegression
# Fold 1: Train MAE 480.65, RMSE 633.28 | Val MAE 1038.10, RMSE 1371.85
# Fold 2: Train MAE 580.66, RMSE 811.65 | Val MAE 2497.55, RMSE 4152.90
# Fold 3: Train MAE 1072.96, RMSE 1740.43 | Val MAE 5018.42, RMSE 6262.95
# Fold 4: Train MAE 1754.93, RMSE 2791.73 | Val MAE 1357.17, RMSE 1977.87
# Fold 5: Train MAE 1662.58, RMSE 2644.51 | Val MAE 2282.23, RMSE 3337.48
# Fold 6: Train MAE 1773.42, RMSE 2766.25 | Val MAE 4333.04, RMSE 5557.15
# Fold 7: Train MAE 2103.17, RMSE 3239.75 | Val MAE 3765.72, RMSE 5102.06
#
#  Modelo: KNN
# Fold 1: Train MAE 399.43, RMSE 612.35 | Val MAE 1169.72, RMSE 1471.56
# Fold 2: Train MAE 502.93, RMSE 746.26 | Val MAE 12430.38, RMSE 20751.98
# Fold 3: Train MAE 826.86, RMSE 1493.63 | Val MAE 6223.47, RMSE 7510.65
# Fold 4: Train MAE 1809.68, RMSE 2835.34 | Val MAE 8402.38, RMSE 9469.54
# Fold 5: Train MAE 1748.91, RMSE 2691.15 | Val MAE 5338.02, RMSE 6841.62
# Fold 6: Train MAE 1974.34, RMSE 2991.56 | Val MAE 24329.98, RMSE 28420.71
# Fold 7: Train MAE 2486.13, RMSE 3787.67 | Val MAE 5483.89, RMSE 7112.32
#
#  Modelo: DecisionTree
# Fold 1: Train MAE 0.00, RMSE 0.00 | Val MAE 1218.04, RMSE 1528.16
# Fold 2: Train MAE 0.00, RMSE 0.00 | Val MAE 12688.34, RMSE 21170.48
# Fold 3: Train MAE 0.00, RMSE 0.00 | Val MAE 8872.52, RMSE 10626.39
# Fold 4: Train MAE 0.00, RMSE 0.00 | Val MAE 8780.19, RMSE 9720.74
# Fold 5: Train MAE 0.00, RMSE 0.00 | Val MAE 5110.87, RMSE 6693.01
# Fold 6: Train MAE 0.00, RMSE 0.00 | Val MAE 25684.30, RMSE 30463.51
# Fold 7: Train MAE 0.00, RMSE 0.00 | Val MAE 7984.05, RMSE 10637.08
#
#  Modelo: RandomForest
# Fold 1: Train MAE 98.13, RMSE 159.41 | Val MAE 1212.40, RMSE 1566.68
# Fold 2: Train MAE 111.88, RMSE 173.90 | Val MAE 12399.96, RMSE 20936.13
# Fold 3: Train MAE 164.78, RMSE 302.37 | Val MAE 9006.42, RMSE 10554.14
# Fold 4: Train MAE 337.65, RMSE 622.13 | Val MAE 6778.84, RMSE 7806.19
# Fold 5: Train MAE 328.32, RMSE 606.48 | Val MAE 3992.88, RMSE 5462.23
# Fold 6: Train MAE 380.65, RMSE 691.22 | Val MAE 24073.24, RMSE 28622.74
# Fold 7: Train MAE 444.84, RMSE 778.06 | Val MAE 5844.82, RMSE 7715.56

# %%
# features y targets ya definidos

# diccionario para guardar pesos por fold/epoch
model_weights_by_horizon = {}

# Callback para guardar pesos
class OurCustomCallback(Callback):
    def __init__(self, horizon):
        super().__init__()
        self.horizon = horizon
        
    def on_epoch_end(self, epoch, logs=None):
        import copy
        if self.horizon not in model_weights_by_horizon:
            model_weights_by_horizon[self.horizon] = {}
        model_weights_by_horizon[self.horizon][epoch] = copy.deepcopy(self.model.get_weights())

# función para crear un modelo base
def create_mlp_model(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(128, activation='relu'),
        Dropout(0.1),
        Dense(128, activation='relu'), #Cambio la activacion de relu a elu
        Dense(64, activation='relu'),
        Dense(1, activation='linear')  # salida para un solo target
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae','mse'])
    return model

# %%
# para guardar resultados
cv_results_nn = {}

# escalador
scaler = RobustScaler()

# early stopping para evitar sobreajuste
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

for i, target in enumerate(targets, start=1):
    print(f"\n Entrenando modelo NN para {target}")
    cv_results_nn[target] = []

    X = train_val_df[features].values
    y = train_val_df[[target]].values

    for fold, (train_idx, val_idx) in enumerate(folds_idx[target]):
        print(f"\n Fold {fold+1}/{len(folds_idx[target])}")

        # separar sets
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]


        # Se reemplazó por valores NaN
        imputer = SimpleImputer(strategy='median')
        X_train_imp = imputer.fit_transform(X_train)
        X_val_imp   = imputer.transform(X_val)
        X_train_scaled = scaler.fit_transform(X_train_imp)
        X_val_scaled   = scaler.transform(X_val_imp)


        # crear nuevo modelo
        model = create_mlp_model(X_train_scaled.shape[1])

        # callback personalizado (opcional)
        callback = OurCustomCallback(horizon=i)

        # entrenar
        history = model.fit(
            X_train_scaled, y_train,
            validation_data=(X_val_scaled, y_val),
            epochs=150,
            batch_size=32,
            verbose=0
        )

        # predicciones
        y_pred_train = model.predict(X_train_scaled)
        y_pred_val = model.predict(X_val_scaled)

        # métricas
        mae_train = mean_absolute_error(y_train, y_pred_train)
        rmse_train = mean_squared_error(y_train, y_pred_train) ** 0.5
        mape_train = mean_absolute_percentage_error(y_train, y_pred_train)

        mae_val = mean_absolute_error(y_val, y_pred_val)
        rmse_val = mean_squared_error(y_val, y_pred_val) ** 0.5
        mape_val = mean_absolute_percentage_error(y_val, y_pred_val)

        print(
            f"Fold {fold+1}: "
            f"Train -> MAE={mae_train:.4f}, RMSE={rmse_train:.4f} | "
            f"Val -> MAE={mae_val:.4f}, RMSE={rmse_val:.4f}"
        )

        # guardar resultados
        cv_results_nn[target].append({
            'fold': fold+1,
            'MAE_train': mae_train,
            'RMSE_train': rmse_train,
            'MAPE_train': mape_train,
            'MAE_val': mae_val,
            'RMSE_val': rmse_val,
            'MAPE_val': mape_val
        })

# promedio final por target
print("\n Resultados Promedio por Horizonte")
for target in targets:
    mae_train_mean = np.mean([r['MAE_train'] for r in cv_results_nn[target]])
    mae_val_mean = np.mean([r['MAE_val'] for r in cv_results_nn[target]])
    rmse_train_mean = np.mean([r['RMSE_train'] for r in cv_results_nn[target]])
    rmse_val_mean = np.mean([r['RMSE_val'] for r in cv_results_nn[target]])

    print(
        f"{target}: "
        f"Train -> MAE={mae_train_mean:.4f}, RMSE={rmse_train_mean:.4f} | "
        f"Val -> MAE={mae_val_mean:.4f}, RMSE={rmse_val_mean:.4f}"
    )
# Out:
#  Entrenando modelo NN para Close_t+1
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=241.9059, RMSE=324.8377 | Val -> MAE=2832.3691, RMSE=3765.8081
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=203.5499, RMSE=297.2176 | Val -> MAE=1217.0387, RMSE=1770.8793
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3: Train -> MAE=338.7321, RMSE=631.1905 | Val -> MAE=2480.6821, RMSE=3085.5939
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=804.4959, RMSE=1351.8604 | Val -> MAE=825.7807, RMSE=1078.8780
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=719.4754, RMSE=1156.1192 | Val -> MAE=928.8592, RMSE=1464.4096
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 6: Train -> MAE=680.9303, RMSE=1113.9163 | Val -> MAE=2930.5107, RMSE=3438.9124
#
#  Entrenando modelo NN para Close_t+2
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=300.2493, RMSE=410.0465 | Val -> MAE=2784.6423, RMSE=3715.6008
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=279.1537, RMSE=405.9114 | Val -> MAE=1369.3225, RMSE=2074.5592
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3: Train -> MAE=477.6877, RMSE=885.2074 | Val -> MAE=4074.1456, RMSE=4912.8046
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4: Train -> MAE=858.0700, RMSE=1473.9131 | Val -> MAE=1139.0977, RMSE=1486.1642
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=880.4089, RMSE=1458.9280 | Val -> MAE=1403.7351, RMSE=1889.7261
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 6: Train -> MAE=867.2769, RMSE=1439.4826 | Val -> MAE=2884.8486, RMSE=3628.6249
#
#  Entrenando modelo NN para Close_t+3
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=344.2231, RMSE=470.0538 | Val -> MAE=1975.7974, RMSE=2738.7747
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=342.2525, RMSE=477.5609 | Val -> MAE=1409.7946, RMSE=2164.6570
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3: Train -> MAE=568.1969, RMSE=1040.9890 | Val -> MAE=4877.8804, RMSE=5896.2956
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=1080.2666, RMSE=1810.5702 | Val -> MAE=1379.4063, RMSE=1804.4755
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=1044.1724, RMSE=1698.0891 | Val -> MAE=1640.8051, RMSE=2191.4257
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 6: Train -> MAE=1116.3426, RMSE=1758.3644 | Val -> MAE=3667.4518, RMSE=4493.0217
#
#  Entrenando modelo NN para Close_t+4
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 1: Train -> MAE=370.5643, RMSE=513.7944 | Val -> MAE=2098.9308, RMSE=2877.7789
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=394.2176, RMSE=542.0698 | Val -> MAE=1548.8916, RMSE=2599.6352
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3: Train -> MAE=755.2426, RMSE=1352.5685 | Val -> MAE=6397.1327, RMSE=7626.0122
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=1211.4926, RMSE=2035.8468 | Val -> MAE=1337.5282, RMSE=1823.2572
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=1213.3291, RMSE=1959.7143 | Val -> MAE=1641.5656, RMSE=2498.1022
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 6: Train -> MAE=1286.1000, RMSE=2037.9340 | Val -> MAE=3762.8497, RMSE=4676.3096
#
#  Entrenando modelo NN para Close_t+5
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=405.0743, RMSE=545.0404 | Val -> MAE=1979.7418, RMSE=2784.7147
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=425.2455, RMSE=582.3850 | Val -> MAE=2146.5196, RMSE=2934.4100
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3: Train -> MAE=696.0853, RMSE=1248.1904 | Val -> MAE=4248.6506, RMSE=5444.1533
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=1414.6545, RMSE=2326.0759 | Val -> MAE=1394.8668, RMSE=2058.1405
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# Fold 5: Train -> MAE=1398.7815, RMSE=2235.6320 | Val -> MAE=1778.3196, RMSE=2663.6860
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 6: Train -> MAE=1427.1383, RMSE=2271.3367 | Val -> MAE=4674.2548, RMSE=5718.6643
#
#  Entrenando modelo NN para Close_t+6
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=426.8656, RMSE=577.7587 | Val -> MAE=1954.8412, RMSE=2814.1983
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=472.3917, RMSE=635.5151 | Val -> MAE=1906.9549, RMSE=3244.2443
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3: Train -> MAE=787.4059, RMSE=1346.9625 | Val -> MAE=6018.3182, RMSE=7391.8782
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=1411.6317, RMSE=2350.7660 | Val -> MAE=2192.0244, RMSE=2789.9680
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=1438.6001, RMSE=2305.5172 | Val -> MAE=2094.2662, RMSE=3036.2944
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 6: Train -> MAE=1509.6221, RMSE=2425.0153 | Val -> MAE=4326.9301, RMSE=5425.3176
#
#  Entrenando modelo NN para Close_t+7
#
#  Fold 1/6
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 1: Train -> MAE=457.8694, RMSE=622.0421 | Val -> MAE=2040.4096, RMSE=2961.6330
#
#  Fold 2/6
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2: Train -> MAE=482.2155, RMSE=654.6296 | Val -> MAE=2337.6939, RMSE=3807.6399
#
#  Fold 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3: Train -> MAE=845.2138, RMSE=1445.6421 | Val -> MAE=6588.5284, RMSE=8068.6686
#
#  Fold 4/6
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 4: Train -> MAE=1629.7663, RMSE=2652.3003 | Val -> MAE=1747.9462, RMSE=2531.8968
#
#  Fold 5/6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 5: Train -> MAE=1563.4832, RMSE=2510.0689 | Val -> MAE=2137.2668, RMSE=3152.8693
#
#  Fold 6/6
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 6: Train -> MAE=1581.4947, RMSE=2546.9688 | Val -> MAE=4512.5775, RMSE=5655.2392
#
#  Resultados Promedio por Horizonte
# Close_t+1: Train -> MAE=498.1816, RMSE=812.5236 | Val -> MAE=1869.2067, RMSE=2434.0802
# Close_t+2: Train -> MAE=610.4744, RMSE=1012.2481 | Val -> MAE=2275.9653, RMSE=2951.2466
# Close_t+3: Train -> MAE=749.2424, RMSE=1209.2712 | Val -> MAE=2491.8559, RMSE=3214.7750
# Close_t+4: Train -> MAE=871.8244, RMSE=1406.9880 | Val -> MAE=2797.8164, RMSE=3683.5159
# Close_t+5: Train -> MAE=961.1633, RMSE=1534.7768 | Val -> MAE=2703.7255, RMSE=3600.6281
# Close_t+6: Train -> MAE=1007.7528, RMSE=1606.9225 | Val -> MAE=3082.2225, RMSE=4116.9834
# Close_t+7: Train -> MAE=1093.3405, RMSE=1738.6086 | Val -> MAE=3227.4038, RMSE=4362.9911

# %%
import os
import joblib  # para guardar el scaler

# directorio para guardar modelos
output_dir = "./models_final"
os.makedirs(output_dir, exist_ok=True)

# diccionario para guardar modelos y resultados
final_models = {}
final_metrics = {}

# iterar sobre los 7 horizontes
for i, target in enumerate(targets, start=1):
    print(f"\n Entrenando modelo final para {target}")
    
    # X e y completos (train + val)
    X = train_val_df[features].values
    y = train_val_df[[target]].values

    # imputar NaN antes de escalar -- Evitar error NaN
    imputer_final = SimpleImputer(strategy='median')
    X_imp = imputer_final.fit_transform(X)
    # escalar
    scaler_final = RobustScaler()
    X_scaled = scaler_final.fit_transform(X_imp)
    
    # crear modelo
    model = create_mlp_model(X_scaled.shape[1])

    # entrenar
    history = model.fit(
        X_scaled, y,
        epochs=200,
        batch_size=32,
        verbose=0
    )

    # predicciones sobre todo el dataset
    y_pred = model.predict(X_scaled)

    # calcular metricas
    mae = mean_absolute_error(y, y_pred)
    rmse = mean_squared_error(y, y_pred) ** 0.5
    mape = mean_absolute_percentage_error(y, y_pred)

    print(f"{target} -> MAE: {mae:.4f}, RMSE: {rmse:.4f}, MAPE: {mape:.4f}")

    model.save(os.path.join(output_dir, f"mlp_{target}.keras"))
    joblib.dump(scaler_final,  os.path.join(output_dir, f"scaler_{target}.pkl"))
    joblib.dump(imputer_final, os.path.join(output_dir, f"imputer_{target}.pkl"))
    print(f"artefactos guardados en {output_dir}")

    # guardar en diccionario para uso inmediato
    final_models[target] = {
        "model": model,
        "scaler": scaler_final
    }

    # guardar metricas
    final_metrics[target] = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape
    }

print("\n Todos los modelos finales, scalers y metricas guardados")
final_metrics[target] = {"MAE": mae, "RMSE": rmse, "MAPE": mape}
# Out:
#  Entrenando modelo final para Close_t+1
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+1 -> MAE: 804.7462, RMSE: 1311.1899, MAPE: 0.0316
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+2
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+2 -> MAE: 1081.7860, RMSE: 1754.8643, MAPE: 0.0398
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+3
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+3 -> MAE: 1314.3934, RMSE: 2085.3223, MAPE: 0.0486
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+4
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+4 -> MAE: 1598.2490, RMSE: 2535.7922, MAPE: 0.0568
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+5
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+5 -> MAE: 1637.9016, RMSE: 2597.3577, MAPE: 0.0584
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+6
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+6 -> MAE: 1775.7432, RMSE: 2824.4847, MAPE: 0.0650
# artefactos guardados en ./models_final
#
#  Entrenando modelo final para Close_t+7
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+7 -> MAE: 1905.4512, RMSE: 3006.1113, MAPE: 0.0689
# artefactos guardados en ./models_final
#
#  Todos los modelos finales, scalers y metricas guardados

# %%
# diccionario para guardar métricas de test
test_metrics = {}

for target in targets:
    print(f"\n Evaluando modelo en test para {target}")

    # obtener modelo y scaler desde final_models
    model = final_models[target]["model"]
    scaler = final_models[target]["scaler"]

    # preparar X e y de test
    X_test = test_df[features].values
    y_test = test_df[[target]].values
        
     # aplicar los mismos artefactos del train, sin refitear
    X_test_imp    = imputer_final.transform(X_test)
    X_test_scaled = scaler.transform(X_test_imp)

    # predecir
    y_pred_test = model.predict(X_test_scaled)

    # calcular métricas
    mae = mean_absolute_error(y_test, y_pred_test)
    rmse = mean_squared_error(y_test, y_pred_test) ** 0.5
    mape = mean_absolute_percentage_error(y_test, y_pred_test)

    print(f"{target} -> MAE: {mae:.4f}, RMSE: {rmse:.4f}, MAPE: {mape:.4f}")

    # guardar métricas
    test_metrics[target] = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape
    }

print("\n métricas finales sobre test")
for target, met in test_metrics.items():
    print(f"{target}: MAE={met['MAE']:.4f}, RMSE={met['RMSE']:.4f}, MAPE={met['MAPE']:.4f}")
# Out:
#  Evaluando modelo en test para Close_t+1
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+1 -> MAE: 1554.3058, RMSE: 2121.4905, MAPE: 0.0176
#
#  Evaluando modelo en test para Close_t+2
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+2 -> MAE: 2205.1709, RMSE: 2906.7629, MAPE: 0.0247
#
#  Evaluando modelo en test para Close_t+3
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+3 -> MAE: 2487.8632, RMSE: 3340.0252, MAPE: 0.0284
#
#  Evaluando modelo en test para Close_t+4
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+4 -> MAE: 3601.7649, RMSE: 4625.4356, MAPE: 0.0391
#
#  Evaluando modelo en test para Close_t+5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+5 -> MAE: 3247.1969, RMSE: 4301.1040, MAPE: 0.0366
#
#  Evaluando modelo en test para Close_t+6
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+6 -> MAE: 3590.7154, RMSE: 4743.3202, MAPE: 0.0404
#
#  Evaluando modelo en test para Close_t+7
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Close_t+7 -> MAE: 3846.7913, RMSE: 5058.0448, MAPE: 0.0440
#
#  métricas finales sobre test
# Close_t+1: MAE=1554.3058, RMSE=2121.4905, MAPE=0.0176
# Close_t+2: MAE=2205.1709, RMSE=2906.7629, MAPE=0.0247
# Close_t+3: MAE=2487.8632, RMSE=3340.0252, MAPE=0.0284
# Close_t+4: MAE=3601.7649, RMSE=4625.4356, MAPE=0.0391
# Close_t+5: MAE=3247.1969, RMSE=4301.1040, MAPE=0.0366
# Close_t+6: MAE=3590.7154, RMSE=4743.3202, MAPE=0.0404
# Close_t+7: MAE=3846.7913, RMSE=5058.0448, MAPE=0.0440
